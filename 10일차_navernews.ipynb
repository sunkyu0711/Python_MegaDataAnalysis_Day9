# %%
# %pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
res
# Out:
# '<!doctype html>\n<html lang="ko" data-useragent="python-requests/2.32.3">\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t\t<meta name="referrer" contents="always">\n\t\t<meta http-equiv="refresh" content="600">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />\n\t\t<meta property="og:title" content="경제 : 네이버 뉴스">\n\t\t<meta property="og:type" content="website">\n\t\t<meta property="og:url" content="https://news.naver.com/breakingnews/section/101/259">\n\t\t<meta property="og:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">\n\t\t<meta property="og:description" content="증권, 금융, 부동산, 기업, 국제 등 경제 분야 뉴스 제공">\n\t\t<meta property="og:article:author" content="네이버">\n\t\t<meta name="twitter:card" content="summary">\n\t\t<meta name="twitter:title" content="경제 : 네이버 뉴스">\n\t\t<meta name="twitter:site" conte
# ...

# %%
soup=BeautifulSoup(res) # parsing. 여기까지가 기본 정석임
soup
# Out:
# <!DOCTYPE html>
# <html data-useragent="python-requests/2.32.3" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="경제 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/breakingnews/section/101/259" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="증권, 금융, 부동산, 기업, 국제 등 경제 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="경제 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# ...

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list')
temp
# Out:
# <ul class="sa_list">
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000FF_000000000000000005304681" data-imp-url="https://n.news.naver.com/mnews/article/014/0005304681" data-rank="1" href="https://n.news.naver.com/mnews/article/014/0005304681">
# <img alt="'금융지주 핀테크 출자소유 규제 완화' 금융위, K-핀테크 스케일업 지원 나선다" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/014/2025/02/06/5304681.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# ...

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li')
temp
# Out:
# [<li class="sa_item _LAZY_LOADING_WRAP">
#  <div class="sa_item_inner">
#  <div class="sa_item_flex">
#  <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
#  <div class="sa_thumb_inner">
#  <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000FF_000000000000000005304681" data-imp-url="https://n.news.naver.com/mnews/article/014/0005304681" data-rank="1" href="https://n.news.naver.com/mnews/article/014/0005304681">
#  <img alt="'금융지주 핀테크 출자소유 규제 완화' 금융위, K-핀테크 스케일업 지원 나선다" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/014/2025/02/06/5304681.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
#  </a>
#  </div>
#  </div>
#  <div class="sa_text">
# ...

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li')
len(temp)
# Out:
# 6

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li')
temp[1]
# Out:
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000E7_000000000000000005938093" data-imp-url="https://n.news.naver.com/mnews/article/018/0005938093" data-rank="2" href="https://n.news.naver.com/mnews/article/018/0005938093">
# <img alt='[마켓인]얼라인파트너스, 코웨이에 "집중투표제 도입·사외이사 선임" 주주제안' class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/018/2025/02/06/5938093.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# ...

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li')
temp[1].select_one('strong.sa_text_strong').text
# Out:
# '[마켓인]얼라인파트너스, 코웨이에 "집중투표제 도입·사외이사 선임" 주주제안'

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li')
temp[0].select_one('strong.sa_text_strong').text
# Out:
# "'금융지주 핀테크 출자소유 규제 완화' 금융위, K-핀테크 스케일업 지원 나선다"

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li')
temp[5].select_one('strong.sa_text_strong').text
# Out:
# '농협금융 “보이스피싱 등 비대면 금융사고 예방 만전”'

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li')
print(temp[0].select_one('div.sa_text_datetime.is_recent').text) # print 빼면 양 끝에 /n이 보임
# Out:
# 1분전

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li')
temp[0].select_one('a')['href']
# Out:
# 'https://n.news.naver.com/mnews/article/014/0005304681'

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li')
print(temp[0].select_one('strong.sa_text_strong').text)
print(temp[0].select_one('div.sa_text_datetime.is_recent').text)
print(temp[0].select_one('a')['href'])
# Out:
# '금융지주 핀테크 출자소유 규제 완화' 금융위, K-핀테크 스케일업 지원 나선다
#
# 1분전
#
# https://n.news.naver.com/mnews/article/014/0005304681

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li')

for li in temp:
    new_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    print(new_info)
# Out:
# {'title': "'금융지주 핀테크 출자소유 규제 완화' 금융위, K-핀테크 스케일업 지원 나선다", 'date': '\n1분전\n', 'news_url': 'https://n.news.naver.com/mnews/article/014/0005304681'}
# {'title': '[마켓인]얼라인파트너스, 코웨이에 "집중투표제 도입·사외이사 선임" 주주제안', 'date': '\n3분전\n', 'news_url': 'https://n.news.naver.com/mnews/article/018/0005938093'}
# {'title': 'NH농협금융 “소비자보호업무 역량 강화 추진”', 'date': '\n3분전\n', 'news_url': 'https://n.news.naver.com/mnews/article/016/0002425074'}
# {'title': '우리銀, NFT 발행·공유 가능한 전자지갑 서비스 출시', 'date': '\n3분전\n', 'news_url': 'https://n.news.naver.com/mnews/article/018/0005938091'}
# {'title': '우리금융硏 “한은, 2월 기준금리 0.25%p 인하할 것”', 'date': '\n4분전\n', 'news_url': 'https://n.news.naver.com/mnews/article/016/0002425073'}
# {'title': '농협금융 “보이스피싱 등 비대면 금융사고 예방 만전”', 'date': '\n4분전\n', 'news_url': 'https://n.news.naver.com/mnews/article/018/0005938089'}

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li')

news_list=[]
for li in temp:
    news_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    news_list.append(news_info)

news_list
# Out:
# [{'title': "'금융지주 핀테크 출자소유 규제 완화' 금융위, K-핀테크 스케일업 지원 나선다",
#   'date': '\n1분전\n',
#   'news_url': 'https://n.news.naver.com/mnews/article/014/0005304681'},
#  {'title': '[마켓인]얼라인파트너스, 코웨이에 "집중투표제 도입·사외이사 선임" 주주제안',
#   'date': '\n3분전\n',
#   'news_url': 'https://n.news.naver.com/mnews/article/018/0005938093'},
#  {'title': 'NH농협금융 “소비자보호업무 역량 강화 추진”',
#   'date': '\n3분전\n',
#   'news_url': 'https://n.news.naver.com/mnews/article/016/0002425074'},
#  {'title': '우리銀, NFT 발행·공유 가능한 전자지갑 서비스 출시',
#   'date': '\n3분전\n',
#   'news_url': 'https://n.news.naver.com/mnews/article/018/0005938091'},
#  {'title': '우리금융硏 “한은, 2월 기준금리 0.25%p 인하할 것”',
#   'date': '\n4분전\n',
#   'news_url': 'https://n.news.naver.com/mnews/article/016/0002425073'},
#  {'title': '농협금융 “보이스피싱 등 비대면 금융사고 예방 만전”',
#   'date': '\n4분전\n',
#   'news_url': 'https://n.news.naver.com/mnews/article/018/0005938089'}]

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li')

news_list=[]
for li in temp:
    news_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    news_list.append(news_info)

news_list[1]
# Out:
# {'title': '[마켓인]얼라인파트너스, 코웨이에 "집중투표제 도입·사외이사 선임" 주주제안',
#  'date': '\n3분전\n',
#  'news_url': 'https://n.news.naver.com/mnews/article/018/0005938093'}

# %%
# 6개인데, 상위 5개만 가져오기

url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li',limit=5)

news_list=[]
for li in temp:
    news_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    news_list.append(news_info)

news_list
# Out:
# [{'title': "'금융지주 핀테크 출자소유 규제 완화' 금융위, K-핀테크 스케일업 지원 나선다",
#   'date': '\n1분전\n',
#   'news_url': 'https://n.news.naver.com/mnews/article/014/0005304681'},
#  {'title': '[마켓인]얼라인파트너스, 코웨이에 "집중투표제 도입·사외이사 선임" 주주제안',
#   'date': '\n3분전\n',
#   'news_url': 'https://n.news.naver.com/mnews/article/018/0005938093'},
#  {'title': 'NH농협금융 “소비자보호업무 역량 강화 추진”',
#   'date': '\n3분전\n',
#   'news_url': 'https://n.news.naver.com/mnews/article/016/0002425074'},
#  {'title': '우리銀, NFT 발행·공유 가능한 전자지갑 서비스 출시',
#   'date': '\n3분전\n',
#   'news_url': 'https://n.news.naver.com/mnews/article/018/0005938091'},
#  {'title': '우리금융硏 “한은, 2월 기준금리 0.25%p 인하할 것”',
#   'date': '\n4분전\n',
#   'news_url': 'https://n.news.naver.com/mnews/article/016/0002425073'}]

# %%
# 뉴스 본문 가져오기

url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li',limit=5)

news_list=[]
for li in temp:
    news_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    news_list.append(news_info)

for news in news_list:
    print(news)
# Out:
# {'title': "'금융지주 핀테크 출자소유 규제 완화' 금융위, K-핀테크 스케일업 지원 나선다", 'date': '\n1분전\n', 'news_url': 'https://n.news.naver.com/mnews/article/014/0005304681'}
# {'title': '[마켓인]얼라인파트너스, 코웨이에 "집중투표제 도입·사외이사 선임" 주주제안', 'date': '\n3분전\n', 'news_url': 'https://n.news.naver.com/mnews/article/018/0005938093'}
# {'title': 'NH농협금융 “소비자보호업무 역량 강화 추진”', 'date': '\n3분전\n', 'news_url': 'https://n.news.naver.com/mnews/article/016/0002425074'}
# {'title': '우리銀, NFT 발행·공유 가능한 전자지갑 서비스 출시', 'date': '\n3분전\n', 'news_url': 'https://n.news.naver.com/mnews/article/018/0005938091'}
# {'title': '우리금융硏 “한은, 2월 기준금리 0.25%p 인하할 것”', 'date': '\n4분전\n', 'news_url': 'https://n.news.naver.com/mnews/article/016/0002425073'}

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li',limit=5)

news_list=[]
for li in temp:
    news_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    news_list.append(news_info)

for news in news_list:
    print(news['news_url'])
# Out:
# https://n.news.naver.com/mnews/article/014/0005304681
# https://n.news.naver.com/mnews/article/018/0005938093
# https://n.news.naver.com/mnews/article/016/0002425074
# https://n.news.naver.com/mnews/article/018/0005938091
# https://n.news.naver.com/mnews/article/016/0002425073

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li',limit=5)

news_list=[]
for li in temp:
    news_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    news_list.append(news_info)

for news in news_list:
    news_url=news['news_url']
    print(news_url)
    res=requests.get(news_url).text
    soup=BeautifulSoup(res)
    print(soup)
# Out:
# https://n.news.naver.com/mnews/article/014/0005304681
# <!DOCTYPE html>
# <html data-useragent="python-requests/2.32.3" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="'금융지주 핀테크 출자소유 규제 완화' 금융위, K-핀테크 스케일업 지원 나선다" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://n.news.naver.com/mnews/article/014/0005304681" property="og:url"/>
# <meta content="https://imgnews.pstatic.net/image/014/2025/02/06/0005304681_001_20250206163712618.jpg?type=w800" property="og:image"/>
# <meta content="금융위원회가 올해 금융지주회사의 핀테크에 대한 출자·소유 관련 규제를 완화하고 금융사 핀테크랩과 공동으로 해외 현지 보육 등을 실시하는 등 'K-핀테크' 글로벌화를 위해 적극 나서기로 했다. 김 위원장은 6일 서울 " property="og:description"/>
# <meta content="파이낸셜뉴스 | 네이버" property="og:article:author"/>
# ...

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li',limit=5)

news_list=[]
for li in temp:
    news_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    news_list.append(news_info)

for news in news_list:
    news_url=news['news_url']
    print(news_url)
    res=requests.get(news_url).text
    soup=BeautifulSoup(res)
    print(soup.select_one('article.go_trans._article_content').text)
# Out:
# https://n.news.naver.com/mnews/article/014/0005304681
#
#
#
#
#
# ...

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li',limit=5)

news_list=[]
for li in temp:
    news_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    news_list.append(news_info)

for news in news_list:
    news_url=news['news_url']
    print(news_url)
    res=requests.get(news_url).text
    soup=BeautifulSoup(res)
    body=soup.select_one('article.go_trans._article_content')
    news_content=body.text.replace('\n','')
    print(news_content)
# Out:
# https://n.news.naver.com/mnews/article/014/0005304681
# ...

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li',limit=5)

news_list=[]
for li in temp:
    news_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    news_list.append(news_info)

for news in news_list:
    news_url=news['news_url']
    print(news_url)
    res=requests.get(news_url).text
    soup=BeautifulSoup(res)
    body=soup.select_one('article.go_trans._article_content')
    news_content=body.text.replace('\n','').strip()
    print(news_content)
# Out:
# https://n.news.naver.com/mnews/article/014/0005304681
# ...

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li',limit=5)

news_list=[]
for li in temp:
    news_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    news_list.append(news_info)

for news in news_list:
    news_url=news['news_url']
    # print(news_url)
    res=requests.get(news_url).text
    soup=BeautifulSoup(res)
    body=soup.select_one('article.go_trans._article_content')
    news_content=body.text.replace('\n','').strip()
    news['news_content']=news_content

news_list
# Out:
# [{'title': "'금융지주 핀테크 출자소유 규제 완화' 금융위, K-핀테크 스케일업 지원 나선다",
#   'date': '\n1분전\n',
#   'news_url': 'https://n.news.naver.com/mnews/article/014/0005304681',
# ...

# %%
url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li',limit=5)

news_list=[]
for li in temp:
    news_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    news_list.append(news_info)

for news in news_list:
    news_url=news['news_url']
    # print(news_url)
    res=requests.get(news_url).text
    soup=BeautifulSoup(res)
    body=soup.select_one('article.go_trans._article_content') # 주의: select 함수를 이용할 때에는 공백을 없애야(.으로 메우면 됨)
    news_content=body.text.replace('\n','').strip()
    news['news_content']=news_content

df=pd.DataFrame(news_list)
df
# Out:
#                                           title     date  \
# 0  '금융지주 핀테크 출자소유 규제 완화' 금융위, K-핀테크 스케일업 지원 나선다  \n1분전\n
# 1    [마켓인]얼라인파트너스, 코웨이에 "집중투표제 도입·사외이사 선임" 주주제안  \n3분전\n
# 2                     NH농협금융 “소비자보호업무 역량 강화 추진”  \n3분전\n
# 3                우리銀, NFT 발행·공유 가능한 전자지갑 서비스 출시  \n4분전\n
# 4              우리금융硏 “한은, 2월 기준금리 0.25%p 인하할 것”  \n4분전\n
#
#                                             news_url  \
# 0  https://n.news.naver.com/mnews/article/014/000...
# 1  https://n.news.naver.com/mnews/article/018/000...
# 2  https://n.news.naver.com/mnews/article/016/000...
# 3  https://n.news.naver.com/mnews/article/018/000...
# 4  https://n.news.naver.com/mnews/article/016/000...
#
#                                         news_content
# 0  김병환 금융위원장이 6일 오후 서울 마포구 마포 프론트원에서 열린 제1차 핀테크 지...
# 1  공개질의에 대한 답변 없자 유감 표명코웨이, "1분기 밸류업 계획 때 답할 것"집중...
# 2  2025년 그룹 금융소비자보호협의회 개최NH농협금융은 6일 ‘2025년 제1차 농협...
# 3  NFT 발행, 합성, 공유 등 새로운 디지털 경험 제공[이데일리 김나경 기자] 우리...
# ...

# %%
# 워드클라우드로 시각화

from konlpy.tag import Okt
import collections

url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li',limit=5)

news_list=[]
for li in temp:
    news_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    news_list.append(news_info)

for news in news_list:
    news_url=news['news_url']
    # print(news_url)
    res=requests.get(news_url).text
    soup=BeautifulSoup(res)
    body=soup.select_one('article.go_trans._article_content') # 주의: select 함수를 이용할 때에는 공백을 없애야(.으로 메우면 됨)
    news_content=body.text.replace('\n','').strip()
    news['news_content']=news_content

df=pd.DataFrame(news_list)

okt=Okt()
clist=[]
for word in df['news_content']:
    token=okt.pos(word)
    for word, tag in token:
        if tag in ['Noun','Adjective']:
            clist.append(word)
counts=collections.Counter(clist)
tag=counts.most_common(50)
print(tag)
# Out:
# [('금융', 37), ('테크', 21), ('순이익', 20), ('대비', 20), ('핀', 20), ('은행', 19), ('그룹', 19), ('증가', 18), ('년', 16), ('배당', 15), ('지난해', 13), ('자', 12), ('사주', 12), ('매입', 12), ('지속', 12), ('확대', 12), ('수준', 11), ('계획', 10), ('기록', 10), ('올해', 9), ('소각', 9), ('실적', 9), ('규모', 9), ('를', 9), ('비율', 9), ('등', 9), ('분기', 8), ('말', 8), ('환원', 8), ('기업', 8), ('로', 7), ('자본', 7), ('지표', 7), ('이익', 7), ('실시', 7), ('원', 7), ('달성', 6), ('보통주', 6), ('현금', 6), ('경영', 6), ('은', 6), ('가치', 6), ('제', 6), ('지원', 6), ('최대', 5), ('관리', 5), ('날', 5), ('예정', 5), ('이', 5), ('주주', 5)]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li',limit=5)

news_list=[]
for li in temp:
    news_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    news_list.append(news_info)

for news in news_list:
    news_url=news['news_url']
    # print(news_url)
    res=requests.get(news_url).text
    soup=BeautifulSoup(res)
    body=soup.select_one('article.go_trans._article_content') # 주의: select 함수를 이용할 때에는 공백을 없애야(.으로 메우면 됨)
    news_content=body.text.replace('\n','').strip()
    news['news_content']=news_content

df=pd.DataFrame(news_list)

okt=Okt()
clist=[]
for word in df['news_content']:
    token=okt.pos(word)
    for word, tag in token:
        if tag in ['Noun','Adjective']:
            clist.append(word)
counts=collections.Counter(clist)
tag=counts.most_common(50)

fpath='C:\Windows\Fonts\malgunbd.ttf'
wc=WordCloud(font_path=fpath,background_color='white') # width, height 등의 설정을 해도 됨
cloud=wc.generate_from_frequencies(dict(tag))

plt.figure(figsize=(10,8))
plt.imshow(cloud)
# Out:
# <>:37: SyntaxWarning: invalid escape sequence '\W'
# <>:37: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\sunky\AppData\Local\Temp\ipykernel_13144\196466853.py:37: SyntaxWarning: invalid escape sequence '\W'
#   fpath='C:\Windows\Fonts\malgunbd.ttf'

# %%
# 축 없애기

url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li',limit=5)

news_list=[]
for li in temp:
    news_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    news_list.append(news_info)

for news in news_list:
    news_url=news['news_url']
    # print(news_url)
    res=requests.get(news_url).text
    soup=BeautifulSoup(res)
    body=soup.select_one('article.go_trans._article_content') # 주의: select 함수를 이용할 때에는 공백을 없애야(.으로 메우면 됨)
    news_content=body.text.replace('\n','').strip()
    news['news_content']=news_content

df=pd.DataFrame(news_list)

okt=Okt()
clist=[]
for word in df['news_content']:
    token=okt.pos(word)
    for word, tag in token:
        if tag in ['Noun','Adjective']:
            clist.append(word)
counts=collections.Counter(clist)
tag=counts.most_common(100)

fpath='C:\Windows\Fonts\malgunbd.ttf'
wc=WordCloud(font_path=fpath,background_color='white') # width, height 등의 설정을 해도 됨
cloud=wc.generate_from_frequencies(dict(tag))

plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
# Out:
# <>:36: SyntaxWarning: invalid escape sequence '\W'
# <>:36: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\sunky\AppData\Local\Temp\ipykernel_13144\1771354052.py:36: SyntaxWarning: invalid escape sequence '\W'
#   fpath='C:\Windows\Fonts\malgunbd.ttf'

# %%
from wordcloud import STOPWORDS

s_words=STOPWORDS.union({'이','비','내','날','전','위','의','현','원','체','수','사','은','것','를','제','로','앞','고','율'})

url='https://news.naver.com/breakingnews/section/101/259'
res=requests.get(url).text
soup=BeautifulSoup(res)
temp=soup.select_one('ul.sa_list').select('li',limit=5)

news_list=[]
for li in temp:
    news_info={'title':li.select_one('strong.sa_text_strong').text,
              'date':li.select_one('div.sa_text_datetime.is_recent').text,
              'news_url':li.select_one('a')['href']}
    news_list.append(news_info)

for news in news_list:
    news_url=news['news_url']
    # print(news_url)
    res=requests.get(news_url).text
    soup=BeautifulSoup(res)
    body=soup.select_one('article.go_trans._article_content') # 주의: select 함수를 이용할 때에는 공백을 없애야(.으로 메우면 됨)
    news_content=body.text.replace('\n','').strip()
    news['news_content']=news_content

df=pd.DataFrame(news_list)

okt=Okt()
clist=[]
for word in df['news_content']:
    token=okt.pos(word)
    for word, tag in token:
        if tag in ['Noun','Adjective']:
            clist.append(word)
counts=collections.Counter(clist)
tag=counts.most_common(100)

fpath='C:\Windows\Fonts\malgunbd.ttf'
wc=WordCloud(font_path=fpath,background_color='white',stopwords=s_words) # 필요 없는 단어 없애기... 안 빠졌네?
cloud=wc.generate_from_frequencies(dict(tag))

plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
# Out:
# <>:38: SyntaxWarning: invalid escape sequence '\W'
# <>:38: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\sunky\AppData\Local\Temp\ipykernel_13144\1340532399.py:38: SyntaxWarning: invalid escape sequence '\W'
#   fpath='C:\Windows\Fonts\malgunbd.ttf'
